# %% [markdown]
# # POSTTEST 3 KECERDASAN BUATAN (VISUALISASI DATA)
# Nama : Denissa Putri Maha Rani |
# NIM  : 2009106079

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_rental=pd.read_csv("CarRentalData.csv")
data_rental
# Out:
#       fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0     ELECTRIC    5.00                13           12       Seattle
# 1     ELECTRIC    5.00                 2            1       Tijeras
# 2       HYBRID    4.92                28           24   Albuquerque
# 3     GASOLINE    5.00                21           20   Albuquerque
# 4     GASOLINE    5.00                 3            1   Albuquerque
# ...        ...     ...               ...          ...           ...
# 5846  GASOLINE    5.00                32           27      Honolulu
# 5847    HYBRID    5.00                17           16          Aiea
# 5848  GASOLINE    4.94                18           17        Kailua
# 5849  GASOLINE     NaN                 1            0       Waipahu
# 5850  GASOLINE    5.00                16           14        Kailua
#
#      location.country  location.latitude  location.longitude location.state  \
# ...

# %% [markdown]
# # Grafik batang

# %%
x = data_rental['vehicle.type']
y = data_rental['rate.daily']

# %%
plt.bar(x, y, color='rosybrown', width=.5, align='center')
plt.title('Perbandingan tarif sewa harian antar kendaraan')
plt.xlabel('Tipe kendaraan')
plt.ylabel('Tarif sewa harian')
plt.show()

# %% [markdown]
# kesimpulan : tipe kendaraan car (mobil keluarga) adalah tipe kendaraan yang paling banyak di sewa di US dan tipe kendaraan yang sedikit peminatnya adalah minivan dengan tarif sewa harian dibawah 200.

# %% [markdown]
# # Grafik PIE

# %%
data_rental['fuelType'].value_counts()
# Out:
# GASOLINE    4810
# ELECTRIC     622
# HYBRID       274
# DIESEL        70
# Name: fuelType, dtype: int64

# %%
bahanBakar = data_rental['fuelType'].value_counts() .rename_axis('Jenis bahan bakar') .reset_index(name='jumlah rating')
rating = data_rental['rating'].value_counts()

# %%
bahanBakar.head()
# Out:
#   Jenis bahan bakar  jumlah rating
# 0          GASOLINE           4810
# 1          ELECTRIC            622
# 2            HYBRID            274
# 3            DIESEL             70

# %%
fig = plt.figure(figsize=(10,10), dpi=100)
colors=('#C9CBA3', '#FFE1A8', '#E26D5C', '#723D46')
plt.pie(data_rental['fuelType'].value_counts(), labels = bahanBakar['Jenis bahan bakar'], autopct='%.1f%%', colors=colors, startangle=100 )
plt.title('Presentase rating kendaraan berdasarkan jenis bahan bakar')
plt.show()

# %% [markdown]
# kesimpulan : masyarakat amerika lebih memilih menggunakan kendaraan berbahan bakar bensin dibanding diesel

# %% [markdown]
# # Scatter plot

# %%
data_kendaraan = pd.read_csv('CarRentalData.csv')
data_kendaraan.head(10)
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0  ELECTRIC    5.00                13           12       Seattle
# 1  ELECTRIC    5.00                 2            1       Tijeras
# 2    HYBRID    4.92                28           24   Albuquerque
# 3  GASOLINE    5.00                21           20   Albuquerque
# 4  GASOLINE    5.00                 3            1   Albuquerque
# 5  GASOLINE    5.00                13           12   Albuquerque
# 6  GASOLINE    4.42                13           12   Albuquerque
# 7  GASOLINE    4.90                12           10   Albuquerque
# 8  GASOLINE    5.00                 1            1   Albuquerque
# 9  GASOLINE    4.76                22           17   Albuquerque
#
#   location.country  location.latitude  location.longitude location.state  \
# 0               US          47.449107         -122.308841             WA
# 1               US          35.111060         -106.276551             NM
# ...

# %%
sns.scatterplot(data = data_kendaraan, x = 'vehicle.year', y = 'rating')
plt.title('data rating kendaraan')
plt.xlabel('tahun kendaraan')
plt.ylabel('rating')
plt.show()

# %% [markdown]
# kesimpulan : rata rata kendaraan yang dibuat tahun 2010-2020 memiliki rating diatas 3 yang berarti semakin lama tahun kendaraan dibuat semakin sedikit yg menyewa dan grafik diatas menggambarkan bahwa tahun pembuatan kendaraan juga menjadi pertimbangan masyarakat ketika ingin menyewa kendaraan.

# %% [markdown]
# # Grafik Heatmap

# %%
data_kendaraan.head()
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0  ELECTRIC    5.00                13           12       Seattle
# 1  ELECTRIC    5.00                 2            1       Tijeras
# 2    HYBRID    4.92                28           24   Albuquerque
# 3  GASOLINE    5.00                21           20   Albuquerque
# 4  GASOLINE    5.00                 3            1   Albuquerque
#
#   location.country  location.latitude  location.longitude location.state  \
# 0               US          47.449107         -122.308841             WA
# 1               US          35.111060         -106.276551             NM
# 2               US          35.127163         -106.566681             NM
# 3               US          35.149726         -106.711425             NM
# 4               US          35.208659         -106.601008             NM
#
#    owner.id  rate.daily vehicle.make vehicle.model vehicle.type  vehicle.year
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data_kendaraan.corr(), center=0, cmap='Blues')
ax.set_title('Korelasi antar atribut pada data rental kendaraan.csv')
# Out:
# Text(0.5, 1.0, 'Korelasi antar atribut pada data rental kendaraan.csv')

# %% [markdown]
# kesimpulan : tahun kendaraan dibuat dan tarif sewa harian cukup berpengaruh terhadap rating sewa kendaraan, tiap lokasi bujur memiliki tarif sewa harian berbeda, tarif sewa kendaraan harian dan tahun kendaraan dibuat berpengaruh terhadap pemberian rating,
