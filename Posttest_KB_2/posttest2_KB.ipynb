# %% [markdown]
# # 2009106079_DENISSA PUTRI MAHA RANI_POSTTEST2

# %%
import pandas as pd
import numpy as np

# %%
data_rental = pd.read_csv("CarRentalData.csv")
data_rental
# Out:
#       fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0     ELECTRIC    5.00                13           12       Seattle
# 1     ELECTRIC    5.00                 2            1       Tijeras
# 2       HYBRID    4.92                28           24   Albuquerque
# 3     GASOLINE    5.00                21           20   Albuquerque
# 4     GASOLINE    5.00                 3            1   Albuquerque
# ...        ...     ...               ...          ...           ...
# 5846  GASOLINE    5.00                32           27      Honolulu
# 5847    HYBRID    5.00                17           16          Aiea
# 5848  GASOLINE    4.94                18           17        Kailua
# 5849  GASOLINE     NaN                 1            0       Waipahu
# 5850  GASOLINE    5.00                16           14        Kailua
#
#      location.country  location.latitude  location.longitude location.state  \
# ...

# %% [markdown]
# # JUMLAH RECORD DLL SERTA DIMASUKKAN KE DICTIONARY

# %% [markdown]
# Dalam dataset rental mobil semua kolom tidak ada nilai yang kosong kecuali kolom
# fuelType dengan 75 missing value
# rating dengan 501 missing value

# %%
data_rental.isna().sum()
# Out:
# fuelType               75
# rating                501
# renterTripsTaken        0
# reviewCount             0
# location.city           0
# location.country        0
# location.latitude       0
# location.longitude      0
# location.state          0
# owner.id                0
# rate.daily              0
# vehicle.make            0
# vehicle.model           0
# vehicle.type            0
# vehicle.year            0
# dtype: int64

# %% [markdown]
# Untuk mengetahui jumlah record :

# %%
data_rental.shape[0]
# Out:
# 5851

# %% [markdown]
# Untuk mengetahui informasi lengkap dataframe  :

# %%
data_rental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5851 entries, 0 to 5850
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fuelType            5776 non-null   object
#  1   rating              5350 non-null   float64
#  2   renterTripsTaken    5851 non-null   int64
#  3   reviewCount         5851 non-null   int64
#  4   location.city       5851 non-null   object
#  5   location.country    5851 non-null   object
#  6   location.latitude   5851 non-null   float64
#  7   location.longitude  5851 non-null   float64
#  8   location.state      5851 non-null   object
#  9   owner.id            5851 non-null   int64
#  10  rate.daily          5851 non-null   int64
#  11  vehicle.make        5851 non-null   object
#  12  vehicle.model       5851 non-null   object
#  13  vehicle.type        5851 non-null   object
#  14  vehicle.year        5851 non-null   int64
# ...

# %% [markdown]
# jumlah record, nama attribute, jumlah attribute dengan tipe objek, jumlah attribute dengan tipe angka, jumlah attribute yang memiliki nilai null.

# %%
jumlahRecord  = len(data_rental)
namaAtribut   = data_rental.columns
atributObjek= len(data_rental.select_dtypes(include=['object']).columns)
atributAngka= len(data_rental.select_dtypes(include=['int64', 'float']).columns)
atributNull = len(data_rental.columns[data_rental.isna().sum() > 0])

dict_record= {
    "Jumlah Record"                 : jumlahRecord,
    "Nama atribut"                  : namaAtribut,
    "Jumlah atribut bertipe objek"  : atributObjek,
    "Jumlah atribut bertipe angka"  : atributAngka,
    "Jumlah atribut bernilai NULL"  : atributNull,
    
}
pd.Series(dict_record)
# Out:
# Jumlah Record                                                                5851
# Nama atribut                    Index(['fuelType', 'rating', 'renterTripsTaken...
# Jumlah atribut bertipe objek                                                    7
# Jumlah atribut bertipe angka                                                    8
# Jumlah atribut bernilai NULL                                                    2
# dtype: object

# %% [markdown]
# # RATA-RATA, STANDAR DEVIASI, NILAI MINIMUM, NILAI MAKSIMUM, Q1,Q2,Q3 ATRIBUT BERTIPE ANGKA

# %% [markdown]
# Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
data_rental.select_dtypes(include=['int64', 'float64']).describe()
# Out:
#             rating  renterTripsTaken  reviewCount  location.latitude  \
# count  5350.000000       5851.000000  5851.000000        5851.000000
# mean      4.920325         33.477354    28.454794          35.582889
# std       0.182425         41.898954    35.136113           6.431408
# min       1.000000          0.000000     0.000000          21.272565
# 25%       4.900000          5.000000     4.000000          30.453623
# 50%       5.000000         18.000000    16.000000          35.554502
# 75%       5.000000         46.000000    39.000000          39.996864
# max       5.000000        395.000000   321.000000          64.893610
#
#        location.longitude      owner.id   rate.daily  vehicle.year
# count         5851.000000  5.851000e+03  5851.000000   5851.000000
# mean           -99.632773  6.034830e+06    93.691506   2015.340113
# std             20.391476  4.646022e+06    96.080920      4.050813
# min           -158.165693  5.105000e+03    20.000000   1955.000000
# ...

# %% [markdown]
# # NILAI KORELASI

# %% [markdown]
# Tampilkan nilai korelasi attribute bertipe angka.

# %%
data_rental.select_dtypes(include=['int64', 'float64']).corr()
# Out:
#                       rating  renterTripsTaken  reviewCount  \
# rating              1.000000         -0.054883    -0.040144
# renterTripsTaken   -0.054883          1.000000     0.994177
# reviewCount        -0.040144          0.994177     1.000000
# location.latitude  -0.002643          0.010998     0.007881
# location.longitude -0.015799         -0.053036    -0.047017
# owner.id            0.051674         -0.331197    -0.325160
# rate.daily          0.086745         -0.104027    -0.100856
# vehicle.year        0.108765         -0.123407    -0.111388
#
#                     location.latitude  location.longitude  owner.id  \
# rating                      -0.002643           -0.015799  0.051674
# renterTripsTaken             0.010998           -0.053036 -0.331197
# reviewCount                  0.007881           -0.047017 -0.325160
# location.latitude            1.000000           -0.012547  0.006748
# location.longitude          -0.012547            1.000000  0.020020
# ...

# %% [markdown]
# # UBAH NILAI SALAH SATU ATRIBUT BERTIPE ANGKA

# %% [markdown]
# Rubah nilai salah satu attribute bertipe angka menjadi desimal 3 angka dibelakang koma jika tidak ada, lakukan sebaliknya (dari desimal menjadi bilangan bulat).

# %% [markdown]
# Melihat tipe data dari atribut 'location.latitude'

# %%
data_rental.dtypes['location.latitude']
# Out:
# dtype('float64')

# %% [markdown]
# Mengubah atribut 'location.latitude' bertipe data float menjadi bilangan bulat

# %%
data_rental.select_dtypes(include=['int64', 'float64']).astype({'location.latitude':'int64'})
# Out:
#       rating  renterTripsTaken  reviewCount  location.latitude  \
# 0       5.00                13           12                 47
# 1       5.00                 2            1                 35
# 2       4.92                28           24                 35
# 3       5.00                21           20                 35
# 4       5.00                 3            1                 35
# ...      ...               ...          ...                ...
# 5846    5.00                32           27                 21
# 5847    5.00                17           16                 21
# 5848    4.94                18           17                 21
# 5849     NaN                 1            0                 21
# 5850    5.00                16           14                 21
#
#       location.longitude  owner.id  rate.daily  vehicle.year
# 0            -122.308841  12847615         135          2019
# 1            -106.276551  15621242         190          2018
# ...

# %% [markdown]
# # 10 RECORD PERTAMA

# %% [markdown]
# Tampilkan 10 record pertama dari attribute bertipe angka.

# %%
data_rental.select_dtypes(include=['int64', 'float64']).head(10)
# Out:
#    rating  renterTripsTaken  reviewCount  location.latitude  \
# 0    5.00                13           12          47.449107
# 1    5.00                 2            1          35.111060
# 2    4.92                28           24          35.127163
# 3    5.00                21           20          35.149726
# 4    5.00                 3            1          35.208659
# 5    5.00                13           12          35.068834
# 6    4.42                13           12          35.045552
# 7    4.90                12           10          35.186542
# 8    5.00                 1            1          35.061213
# 9    4.76                22           17          35.115363
#
#    location.longitude  owner.id  rate.daily  vehicle.year
# 0         -122.308841  12847615         135          2019
# 1         -106.276551  15621242         190          2018
# 2         -106.566681  10199256          35          2012
# 3         -106.711425   9365496          75          2018
# ...

# %% [markdown]
# # Simpan dataset dengan attribute bertipe angka ke dalam file CSV.

# %% [markdown]
# data rental mobil dengan atribut bertipe angka

# %%
data_rental.select_dtypes(include=['int64', 'float64'])
# Out:
#       rating  renterTripsTaken  reviewCount  location.latitude  \
# 0       5.00                13           12          47.449107
# 1       5.00                 2            1          35.111060
# 2       4.92                28           24          35.127163
# 3       5.00                21           20          35.149726
# 4       5.00                 3            1          35.208659
# ...      ...               ...          ...                ...
# 5846    5.00                32           27          21.292950
# 5847    5.00                17           16          21.375507
# 5848    4.94                18           17          21.378719
# 5849     NaN                 1            0          21.376105
# 5850    5.00                16           14          21.378040
#
#       location.longitude  owner.id  rate.daily  vehicle.year
# 0            -122.308841  12847615         135          2019
# 1            -106.276551  15621242         190          2018
# ...

# %% [markdown]
# Menyimpan data set rental mobil dengan atribut bertipe angka ke dalam file csv dengan nama Data_Rental_Angka.csv

# %%
data_rental.select_dtypes(include=['int64', 'float64']).to_csv('Data_Rental_Angka.csv', sep='\t', index=False)
